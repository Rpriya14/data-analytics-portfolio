# %%
import pandas as pd
df=pd.read_csv("pandas_practice_dataset.csv")
print(df)
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      NaN   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      NaN   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years
# 0                 2
# 1                 3
# 2                 1
# 3                 5
# 4                 6
# 5                 2
# 6                 4
# 7                 7

# %%
import os
print(os.listdir())
# Out:
# ['.config', '.ipynb_checkpoints', 'pandas_practice_dataset.csv', 'sample_data']

# %%
print(df)
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      NaN   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      NaN   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years
# 0                 2
# 1                 3
# 2                 1
# 3                 5
# 4                 6
# 5                 2
# 6                 4
# 7                 7

# %% [markdown]
# head -> first five rows

# %%
print(df.head())
# Out:
#    Employee_ID   Name Department        City   Salary  Bonus  Experience_Years
# 0          101   Ravi      Sales     Chennai  50000.0   5000                 2
# 1          102  Priya         HR     Madurai  40000.0   4000                 3
# 2          103   Arun         IT  Coimbatore      NaN   3000                 1
# 3          104   John      Sales       Delhi  55000.0   5500                 5
# 4          105  Meena    Finance     Chennai  60000.0   6000                 6

# %%
print(df.tail())
# Out:
#    Employee_ID     Name Department       City   Salary  Bonus  \
# 3          104     John      Sales      Delhi  55000.0   5500
# 4          105    Meena    Finance    Chennai  60000.0   6000
# 5          106  Karthik         IT  Bangalore  45000.0   4500
# 6          107    Divya         HR    Madurai      NaN   3500
# 7          108     Sara      Sales      Delhi  70000.0   7000
#
#    Experience_Years
# 3                 5
# 4                 6
# 5                 2
# 6                 4
# 7                 7

# %%
print(df.shape)
# Out:
# (8, 7)

# %%
print(len(df))
# Out:
# 8

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Name', 'Department', 'City', 'Salary', 'Bonus',
#        'Experience_Years'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Employee_ID           int64
# Name                 object
# Department           object
# City                 object
# Salary              float64
# Bonus                 int64
# Experience_Years      int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       8 non-null      int64
#  1   Name              8 non-null      object
#  2   Department        8 non-null      object
#  3   City              8 non-null      object
#  4   Salary            6 non-null      float64
#  5   Bonus             8 non-null      int64
#  6   Experience_Years  8 non-null      int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 580.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        Employee_ID        Salary        Bonus  Experience_Years
# count      8.00000      6.000000     8.000000           8.00000
# mean     104.50000  53333.333333  4812.500000           3.75000
# std        2.44949  10801.234497  1334.634782           2.12132
# min      101.00000  40000.000000  3000.000000           1.00000
# 25%      102.75000  46250.000000  3875.000000           2.00000
# 50%      104.50000  52500.000000  4750.000000           3.50000
# 75%      106.25000  58750.000000  5625.000000           5.25000
# max      108.00000  70000.000000  7000.000000           7.00000

# %%
print(df["Salary"].mean())
# Out:
# 53333.333333333336

# %%
print(df["Salary"].max())
# Out:
# 70000.0

# %%
print(df["Salary"].min())
# Out:
# 40000.0

# %%
print(df["Salary"].sum())
# Out:
# 320000.0

# %%
print(df["Bonus"].mean())
# Out:
# 4812.5

# %%
print(df["Name"])
# Out:
# 0       Ravi
# 1      Priya
# 2       Arun
# 3       John
# 4      Meena
# 5    Karthik
# 6      Divya
# 7       Sara
# Name: Name, dtype: object

# %%
print(df[["Name","Salary"]])
# Out:
#       Name   Salary
# 0     Ravi  50000.0
# 1    Priya  40000.0
# 2     Arun      NaN
# 3     John  55000.0
# 4    Meena  60000.0
# 5  Karthik  45000.0
# 6    Divya      NaN
# 7     Sara  70000.0

# %%
print(df[["Name","Salary","City"]])
# Out:
#       Name   Salary        City
# 0     Ravi  50000.0     Chennai
# 1    Priya  40000.0     Madurai
# 2     Arun      NaN  Coimbatore
# 3     John  55000.0       Delhi
# 4    Meena  60000.0     Chennai
# 5  Karthik  45000.0   Bangalore
# 6    Divya      NaN     Madurai
# 7     Sara  70000.0       Delhi

# %%
print(df[df["Salary"]>50000])
# Out:
#    Employee_ID   Name Department     City   Salary  Bonus  Experience_Years
# 3          104   John      Sales    Delhi  55000.0   5500                 5
# 4          105  Meena    Finance  Chennai  60000.0   6000                 6
# 7          108   Sara      Sales    Delhi  70000.0   7000                 7

# %%
print(df[df["City"]=="Chennai"])
# Out:
#    Employee_ID   Name Department     City   Salary  Bonus  Experience_Years
# 0          101   Ravi      Sales  Chennai  50000.0   5000                 2
# 4          105  Meena    Finance  Chennai  60000.0   6000                 6

# %%
print(df[df["Department"]=="IT"])
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 2          103     Arun         IT  Coimbatore      NaN   3000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
#
#    Experience_Years
# 2                 1
# 5                 2

# %%
print(df[df["Bonus"]>5000])
# Out:
#    Employee_ID   Name Department     City   Salary  Bonus  Experience_Years
# 3          104   John      Sales    Delhi  55000.0   5500                 5
# 4          105  Meena    Finance  Chennai  60000.0   6000                 6
# 7          108   Sara      Sales    Delhi  70000.0   7000                 7

# %%
print(df[df["Experience_Years"]>3])
# Out:
#    Employee_ID   Name Department     City   Salary  Bonus  Experience_Years
# 3          104   John      Sales    Delhi  55000.0   5500                 5
# 4          105  Meena    Finance  Chennai  60000.0   6000                 6
# 6          107  Divya         HR  Madurai      NaN   3500                 4
# 7          108   Sara      Sales    Delhi  70000.0   7000                 7

# %%
print(df.isnull())
# Out:
#    Employee_ID   Name  Department   City  Salary  Bonus  Experience_Years
# 0        False  False       False  False   False  False             False
# 1        False  False       False  False   False  False             False
# 2        False  False       False  False    True  False             False
# 3        False  False       False  False   False  False             False
# 4        False  False       False  False   False  False             False
# 5        False  False       False  False   False  False             False
# 6        False  False       False  False    True  False             False
# 7        False  False       False  False   False  False             False

# %%
print(df.isnull().sum())
# Out:
# Employee_ID         0
# Name                0
# Department          0
# City                0
# Salary              2
# Bonus               0
# Experience_Years    0
# dtype: int64

# %%
df["Salary"]=df["Salary"].fillna(0)
print(df)
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      0.0   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      0.0   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years
# 0                 2
# 1                 3
# 2                 1
# 3                 5
# 4                 6
# 5                 2
# 6                 4
# 7                 7

# %% [markdown]
# NEW COLUMNS CREATE

# %%
df["Tax"]=df["Salary"]*0.05
print(df["Tax"])
# Out:
# 0    2500.0
# 1    2000.0
# 2       0.0
# 3    2750.0
# 4    3000.0
# 5    2250.0
# 6       0.0
# 7    3500.0
# Name: Tax, dtype: float64

# %%
df["NetSalary"] = df["Salary"] - df["Tax"]
print(df)
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      0.0   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      0.0   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years     Tax  NetSalary
# 0                 2  2500.0    47500.0
# 1                 3  2000.0    38000.0
# 2                 1     0.0        0.0
# 3                 5  2750.0    52250.0
# 4                 6  3000.0    57000.0
# 5                 2  2250.0    42750.0
# 6                 4     0.0        0.0
# 7                 7  3500.0    66500.0

# %%
df["FinalSalary"] = df["Salary"] + df["Bonus"]
print(df)
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      0.0   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      0.0   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years     Tax  NetSalary  FinalSalary
# 0                 2  2500.0    47500.0      55000.0
# 1                 3  2000.0    38000.0      44000.0
# 2                 1     0.0        0.0       3000.0
# 3                 5  2750.0    52250.0      60500.0
# 4                 6  3000.0    57000.0      66000.0
# 5                 2  2250.0    42750.0      49500.0
# ...

# %%
print(df.sort_values(by="Salary"))
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 2          103     Arun         IT  Coimbatore      0.0   3000
# 6          107    Divya         HR     Madurai      0.0   3500
# 1          102    Priya         HR     Madurai  40000.0   4000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years     Tax  NetSalary  FinalSalary
# 2                 1     0.0        0.0       3000.0
# 6                 4     0.0        0.0       3500.0
# 1                 3  2000.0    38000.0      44000.0
# 5                 2  2250.0    42750.0      49500.0
# 0                 2  2500.0    47500.0      55000.0
# 3                 5  2750.0    52250.0      60500.0
# ...

# %%
print(df.sort_values(by="Experience_Years",ascending=False))
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 7          108     Sara      Sales       Delhi  70000.0   7000
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 3          104     John      Sales       Delhi  55000.0   5500
# 6          107    Divya         HR     Madurai      0.0   3500
# 1          102    Priya         HR     Madurai  40000.0   4000
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 2          103     Arun         IT  Coimbatore      0.0   3000
#
#    Experience_Years     Tax  NetSalary  FinalSalary
# 7                 7  3500.0    66500.0      77000.0
# 4                 6  3000.0    57000.0      66000.0
# 3                 5  2750.0    52250.0      60500.0
# 6                 4     0.0        0.0       3500.0
# 1                 3  2000.0    38000.0      44000.0
# 0                 2  2500.0    47500.0      55000.0
# ...

# %%
print(df.groupby("City")["Salary"].sum())
# Out:
# City
# Bangalore      45000.0
# Chennai       110000.0
# Coimbatore         0.0
# Delhi         125000.0
# Madurai        40000.0
# Name: Salary, dtype: float64

# %%
print(df.groupby("Department")["Salary"].sum())
# Out:
# Department
# Finance     60000.0
# HR          40000.0
# IT          45000.0
# Sales      175000.0
# Name: Salary, dtype: float64

# %%
print(df.groupby("City")["Salary"].mean())
# Out:
# City
# Bangalore     45000.0
# Chennai       55000.0
# Coimbatore        0.0
# Delhi         62500.0
# Madurai       20000.0
# Name: Salary, dtype: float64

# %%
print(df.loc[0])
# Out:
# Employee_ID             101
# Name                   Ravi
# Department            Sales
# City                Chennai
# Salary              50000.0
# Bonus                  5000
# Experience_Years          2
# Tax                  2500.0
# NetSalary           47500.0
# FinalSalary         55000.0
# Name: 0, dtype: object

# %%
print(df.iloc[1])
# Out:
# Employee_ID             102
# Name                  Priya
# Department               HR
# City                Madurai
# Salary              40000.0
# Bonus                  4000
# Experience_Years          3
# Tax                  2000.0
# NetSalary           38000.0
# FinalSalary         44000.0
# Name: 1, dtype: object

# %%
print(df.loc[0,"Name"])
# Out:
# Ravi

# %%
print(df.iloc[0,1])
# Out:
# Ravi

# %%
df.to_csv("cleaned_dataset.csv",index=False)

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
print(df.drop_duplicates())
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      0.0   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      0.0   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years     Tax  NetSalary  FinalSalary
# 0                 2  2500.0    47500.0      55000.0
# 1                 3  2000.0    38000.0      44000.0
# 2                 1     0.0        0.0       3000.0
# 3                 5  2750.0    52250.0      60500.0
# 4                 6  3000.0    57000.0      66000.0
# 5                 2  2250.0    42750.0      49500.0
# ...

# %%
print(df.isnull())
# Out:
#    Employee_ID   Name  Department   City  Salary  Bonus  Experience_Years  \
# 0        False  False       False  False   False  False             False
# 1        False  False       False  False   False  False             False
# 2        False  False       False  False   False  False             False
# 3        False  False       False  False   False  False             False
# 4        False  False       False  False   False  False             False
# 5        False  False       False  False   False  False             False
# 6        False  False       False  False   False  False             False
# 7        False  False       False  False   False  False             False
#
#      Tax  NetSalary  FinalSalary
# 0  False      False        False
# 1  False      False        False
# 2  False      False        False
# 3  False      False        False
# 4  False      False        False
# 5  False      False        False
# 6  False      False        False
# ...

# %%
print(df.isnull().sum())
# Out:
# Employee_ID         0
# Name                0
# Department          0
# City                0
# Salary              0
# Bonus               0
# Experience_Years    0
# Tax                 0
# NetSalary           0
# FinalSalary         0
# dtype: int64

# %% [markdown]
# remove rows with missing values

# %%
print(df.dropna())
# Out:
#    Employee_ID     Name Department        City   Salary  Bonus  \
# 0          101     Ravi      Sales     Chennai  50000.0   5000
# 1          102    Priya         HR     Madurai  40000.0   4000
# 2          103     Arun         IT  Coimbatore      0.0   3000
# 3          104     John      Sales       Delhi  55000.0   5500
# 4          105    Meena    Finance     Chennai  60000.0   6000
# 5          106  Karthik         IT   Bangalore  45000.0   4500
# 6          107    Divya         HR     Madurai      0.0   3500
# 7          108     Sara      Sales       Delhi  70000.0   7000
#
#    Experience_Years     Tax  NetSalary  FinalSalary
# 0                 2  2500.0    47500.0      55000.0
# 1                 3  2000.0    38000.0      44000.0
# 2                 1     0.0        0.0       3000.0
# 3                 5  2750.0    52250.0      60500.0
# 4                 6  3000.0    57000.0      66000.0
# 5                 2  2250.0    42750.0      49500.0
# ...

# %%
df["Salary"]=df["Salary"].fillna(0)

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
print(df["Salary"])
# Out:
# 0    50000.0
# 1    40000.0
# 2        0.0
# 3    55000.0
# 4    60000.0
# 5    45000.0
# 6        0.0
# 7    70000.0
# Name: Salary, dtype: float64

# %% [markdown]
# drop na -> delete row when it is useless (the row)
#
# fillna -> keep row,replace missing value, use if row is still useful.
#
# dropna = remove ❌
# fillna = replace 🔁

# %%
df.rename(columns={"Salary":"EmployeeSalary"})
# Out:
#    Employee_ID     Name Department        City  EmployeeSalary  Bonus  \
# 0          101     Ravi      Sales     Chennai         50000.0   5000
# 1          102    Priya         HR     Madurai         40000.0   4000
# 2          103     Arun         IT  Coimbatore             0.0   3000
# 3          104     John      Sales       Delhi         55000.0   5500
# 4          105    Meena    Finance     Chennai         60000.0   6000
# 5          106  Karthik         IT   Bangalore         45000.0   4500
# 6          107    Divya         HR     Madurai             0.0   3500
# 7          108     Sara      Sales       Delhi         70000.0   7000
#
#    Experience_Years     Tax  NetSalary  FinalSalary
# 0                 2  2500.0    47500.0      55000.0
# 1                 3  2000.0    38000.0      44000.0
# 2                 1     0.0        0.0       3000.0
# 3                 5  2750.0    52250.0      60500.0
# 4                 6  3000.0    57000.0      66000.0
# ...

# %% [markdown]
# Change datatype 🔄
#
# Sometimes salary comes as text.
#
# Bad:
#
# Salary = "50000"
#
# Should be number.
#
# Check datatype:
#
# print(df.dtypes)
#
# Convert:
#
# df["Salary"] = df["Salary"].astype(float)
#
# Now numeric.
#
# Common company issue.

# %%
df["Salary"]=df["Salary"].astype(float)

# %% [markdown]
# String cleaning ✂️
#
# Sometimes spaces exist.
#
# Example:
#
# " Ravi "
#
# Has extra spaces.
#
# Remove spaces:
#
# df["Name"] = df["Name"].str.strip()
#
# Before:
#
# " Ravi "
#
# After:
#
# "Ravi"
#
# Convert lowercase:
#
# df["City"] = df["City"].str.lower()
#
# Example:
#
# Chennai → chennai
#
# Uppercase:
#
# df["City"] = df["City"].str.upper()
#
# Companies use for standardization.
